# %%
import pandas as pd
emigration_immigration_rates_df=pd.read_excel("C:/Users/13154/Downloads/emigration-immigration-rates.xlsx")
world_data_2023_df=pd.read_csv("C:/Users/13154/Downloads/world-data-2023.csv")

justImportedWorldData = world_data.copy(deep=True)
justImportedEmigrationData = emigration_immigration_rates_df.copy(deep=True)
print(emigration_immigration_rates_df.head)
# Out:
# <bound method NDFrame.head of                    country isoo  year region10_ori iso3  Emigrants_males_HS  \
# 0              Afghanistan  AFG  2020           SA  AFG              199099
# 1                   Angola  AGO  2020          SSA  AGO               52097
# 2                  Albania  ALB  2020      ECA-OTH  ALB               73776
# 3                  Andorra  AND  2020      ECA-HIC  AND                1608
# 4     United Arab Emirates  ARE  2020          GCC  ARE               31501
# ..                     ...  ...   ...          ...  ...                 ...
# 550  Serbia and Montenegro  YUG  2000      ECA-OTH  YUG              120143
# 551           South Africa  ZAF  2000          SSA  ZAF              111792
# 552       Congo, Dem. Rep.  ZAR  2000          SSA  ZAR               53992
# 553                 Zambia  ZMB  2000          SSA  ZMB               16257
# 554               Zimbabwe  ZWE  2000          SSA  ZWE               34579
#
#      Emigrants_males_LS  Emigrants_males  Emigrants_014_male  \
# 0               2393409          2592511              563018
# 1                209843           261940               44123
# 2                426960           500728               45140
# 3                  2647             4256                 430
# 4                 60327            91831               19733
# ..                  ...              ...                 ...
# 550              749976           870119               97932
# 551              128260           240052               10966
# 552              303484           357476               76134
# 553               55600            71857                8896
# 554              147277           181856               13918
#
#      Emigrants_females_HS  ...  immig_rate_female  immig_rate_male  \
# 0                114867.0  ...           0.005801         0.005225
# 1                 54591.0  ...           0.034721         0.036617
# 2                 95576.0  ...           0.017174         0.017423
# 3                  1975.0  ...                NaN              NaN
# 4                 22444.0  ...           0.842381         0.900089
# ..                    ...  ...                ...              ...
# 550               97891.0  ...           0.156939         0.130489
# 551              106381.0  ...           0.027620         0.043704
# 552               34201.0  ...           0.015547         0.015554
# 553               13526.0  ...           0.046976         0.050529
# 554               31298.0  ...           0.037726         0.058034
#
#      Emigrants_total  Immigrants_total  Emigrants_HS_total  \
# 0            4683917            124681            313966.0
# 1             533102            628024            106688.0
# 2             998089             40633            169352.0
# 3               8726             41084              3583.0
# 4             169785           7448633             53945.0
# ..               ...               ...                 ...
# 550          1693847            861143            218034.0
# 551           488941           1054461            218173.0
# 552           724950            398920             88193.0
# 553           150027            271958             29783.0
# 554           349696            326733             65877.0
#
#      Emigrants_LS_total  Immigrants_HS_total  Immigrants_LS_total  \
# 0             4369950.0               1514.0             123166.0
# 1              426419.0              28430.0             599593.0
# 2              828752.0               6708.0              33926.0
# 3                5141.0              13431.0              27644.0
# 4              115840.0            3950992.0            3497643.0
# ..                  ...                  ...                  ...
# 550           1475813.0             144329.0             716814.0
# 551            270768.0             127292.0             927169.0
# 552            636757.0              57050.0             341870.0
# 553            120244.0              18029.0             253929.0
# 554            283819.0              18226.0             308507.0
#
#      Emigrants_014_total  Immigrants_014_total
# 0                1029000                 19417
# 1                  85526                 28410
# 2                  80427                  8177
# 3                    919                  4493
# 4                  36712               1267702
# ..                   ...                   ...
# 550               183922                 14543
# 551                21733                 12716
# 552               152148                 99732
# 553                17931                 66495
# 554                28276                 37430
#
# [555 rows x 60 columns]>

# %%
#using the information from https://www.iban.com/country-codes, we create a mapping from the two letter codes to three letter codes
twoToThreeLetterCountryCodeMapping = {
    "AF": "AFG", "AL": "ALB", "DZ": "DZA", "AS": "ASM", "AD": "AND", "AO": "AGO", "AI": "AIA",
    "AQ": "ATA", "AG": "ATG", "AR": "ARG", "AM": "ARM", "AW": "ABW", "AU": "AUS", "AT": "AUT",
    "AZ": "AZE", "BS": "BHS", "BH": "BHR", "BD": "BGD", "BB": "BRB", "BY": "BLR", "BE": "BEL",
    "BZ": "BLZ", "BJ": "BEN", "BM": "BMU", "BT": "BTN", "BO": "BOL", "BQ": "BES", "BA": "BIH",
    "BW": "BWA", "BV": "BVT", "BR": "BRA", "IO": "IOT", "BN": "BRN", "BG": "BGR", "BF": "BFA",
    "BI": "BDI", "CV": "CPV", "KH": "KHM", "CM": "CMR", "CA": "CAN", "KY": "CYM", "CF": "CAF",
    "TD": "TCD", "CL": "CHL", "CN": "CHN", "CX": "CXR", "CC": "CCK", "CO": "COL", "KM": "COM",
    "CD": "COD", "CG": "COG", "CK": "COK", "CR": "CRI", "HR": "HRV", "CU": "CUB", "CW": "CUW",
    "CY": "CYP", "CZ": "CZE", "CI": "CIV", "DK": "DNK", "DJ": "DJI", "DM": "DMA", "DO": "DOM",
    "EC": "ECU", "EG": "EGY", "SV": "SLV", "GQ": "GNQ", "ER": "ERI", "EE": "EST", "SZ": "SWZ",
    "ET": "ETH", "FK": "FLK", "FO": "FRO", "FJ": "FJI", "FI": "FIN", "FR": "FRA", "GF": "GUF",
    "PF": "PYF", "TF": "ATF", "GA": "GAB", "GM": "GMB", "GE": "GEO", "DE": "DEU", "GH": "GHA",
    "GI": "GIB", "GR": "GRC", "GL": "GRL", "GD": "GRD", "GP": "GLP", "GU": "GUM", "GT": "GTM",
    "GG": "GGY", "GN": "GIN", "GW": "GNB", "GY": "GUY", "HT": "HTI", "HM": "HMD", "VA": "VAT",
    "HN": "HND", "HK": "HKG", "HU": "HUN", "IS": "ISL", "IN": "IND", "ID": "IDN", "IR": "IRN",
    "IQ": "IRQ", "IE": "IRL", "IM": "IMN", "IL": "ISR", "IT": "ITA", "JM": "JAM", "JP": "JPN",
    "JE": "JEY", "JO": "JOR", "KZ": "KAZ", "KE": "KEN", "KI": "KIR", "KP": "PRK", "KR": "KOR",
    "KW": "KWT", "KG": "KGZ", "LA": "LAO", "LV": "LVA", "LB": "LBN", "LS": "LSO", "LR": "LBR",
    "LY": "LBY", "LI": "LIE", "LT": "LTU", "LU": "LUX", "MO": "MAC", "MG": "MDG", "MW": "MWI",
    "MY": "MYS", "MV": "MDV", "ML": "MLI", "MT": "MLT", "MH": "MHL", "MQ": "MTQ", "MR": "MRT",
    "MU": "MUS", "YT": "MYT", "MX": "MEX", "FM": "FSM", "MD": "MDA", "MC": "MCO", "MN": "MNG",
    "ME": "MNE", "MS": "MSR", "MA": "MAR", "MZ": "MOZ", "MM": "MMR", "NA": "NAM", "NR": "NRU",
    "NP": "NPL", "NL": "NLD", "NC": "NCL", "NZ": "NZL", "NI": "NIC", "NE": "NER", "NG": "NGA",
    "NU": "NIU", "NF": "NFK", "MP": "MNP", "NO": "NOR", "OM": "OMN", "PK": "PAK", "PW": "PLW",
    "PS": "PSE", "PA": "PAN", "PG": "PNG", "PY": "PRY", "PE": "PER", "PH": "PHL", "PN": "PCN",
    "PL": "POL", "PT": "PRT", "PR": "PRI", "QA": "QAT", "MK": "MKD", "RO": "ROU", "RU": "RUS",
    "RW": "RWA", "RE": "REU", "BL": "BLM", "SH": "SHN", "KN": "KNA", "LC": "LCA", "MF": "MAF",
    "PM": "SPM", "VC": "VCT", "WS": "WSM", "SM": "SMR", "ST": "STP", "SA": "SAU", "SN": "SEN",
    "RS": "SRB", "SC": "SYC", "SL": "SLE", "SG": "SGP", "SX": "SXM", "SK": "SVK", "SI": "SVN",
    "SB": "SLB", "SO": "SOM", "ZA": "ZAF", "GS": "SGS", "SS": "SSD", "ES": "ESP", "LK": "LKA",
    "SD": "SDN", "SR": "SUR", "SJ": "SJM", "SE": "SWE", "CH": "CHE", "SY": "SYR", "TW": "TWN",
    "TJ": "TJK", "TZ": "TZA", "TH": "THA", "TL": "TLS", "TG": "TGO", "TK": "TKL", "TO": "TON",
    "TT": "TTO", "TN": "TUN", "TR": "TUR", "TM": "TKM", "TC": "TCA", "TV": "TUV", "UG": "UGA",
    "UA": "UKR", "AE": "ARE", "GB": "GBR", "UM": "UMI", "US": "USA", "UY": "URY", "UZ": "UZB",
    "VU": "VUT", "VE": "VEN", "VN": "VNM", "VG": "VGB", "VI": "VIR", "WF": "WLF", "EH": "ESH",
    "YE": "YEM", "ZM": "ZMB", "ZW": "ZWE", "AX": "ALA"}

world_data_2023_df["iso3"] = world_data_2023_df["Abbreviation"].map(twoToThreeLetterCountryCodeMapping)
world_data_2023_df["GDP"] = world_data_2023_df["GDP"].str.replace("$","").str.replace(",","").astype(float)
world_data_2023_df["Minimum wage"] = world_data_2023_df["Minimum wage"].str.replace("$","").str.replace(",","").astype(float)
world_data_2023_df["Unemployment rate"] = world_data_2023_df["Unemployment rate"].str.replace("%","").astype(float)
world_data_2023_df["OOP health expenditure"] = world_data_2023_df["Out of pocket health expenditure"].str.replace("%","").astype(float)
world_data_2023_df["Primary education enrollment"] = world_data_2023_df["Gross primary education enrollment (%)"].str.replace("%","").astype(float)
world_data_2023_df["Tertiary education enrollment"] = world_data_2023_df["Gross tertiary education enrollment (%)"].str.replace("%","").astype(float)

# %%
emigrants_immagrants_totals_2020_df = emigration_immigration_rates_df[emigration_immigration_rates_df["year"] == 2020][["iso3","Emigrants_total","Immigrants_total","emig_rate","immig_rate"]]
emigrants_immagrants_totals_2020_df["iso3"] = emigrants_immagrants_totals_2020_df["iso3"].replace("ZAR","COD")

# %%
columnsFromWorldData = world_data_2023_df[["iso3",
                                           "Birth Rate",
                                           "Infant mortality",
                                           "Physicians per thousand",
                                           "Life expectancy",
                                           "OOP health expenditure",
                                           "GDP",
                                           "Unemployment rate",
                                           "Minimum wage",
                                           "Primary education enrollment",
                                           "Tertiary education enrollment"]]

columnsFromEmigrationImmigrationData = emigrants_immagrants_totals_2020_df

# %%
combinedColumns = pd.merge(columnsFromWorldData,columnsFromEmigrationImmigrationData, on="iso3")
columnTitles = ["Birth Rate",
                "Infant mortality",
                "Physicians per thousand",
                "Life expectancy",
                "OOP health expenditure",
                "GDP",
                "Unemployment rate",
                "Minimum wage",
                "Primary education enrollment",
                "Tertiary education enrollment",
                "Emigrants_total",
                "Immigrants_total",
                "emig_rate",
                "immig_rate"]
 
combinedColumns=combinedColumns.dropna()
print(combinedColumns.columns)
# Out:
# Index(['iso3', 'Birth Rate', 'Infant mortality', 'Physicians per thousand',
#        'Life expectancy', 'OOP health expenditure', 'GDP', 'Unemployment rate',
#        'Minimum wage', 'Primary education enrollment',
#        'Tertiary education enrollment', 'Emigrants_total', 'Immigrants_total',
#        'emig_rate', 'immig_rate'],
#       dtype='object')

# %%
#all of the above code was done by Ian
#used for consistency in data

# %%
# !pip install statsmodels
import statsmodels.api as sm
import numpy as np
import pandas as pd

variables=["Birth Rate",
                "Physicians per thousand",
                "Life expectancy",
                "OOP health expenditure",
                "GDP",
                "Unemployment rate",
                "Minimum wage",
                "Primary education enrollment",
                "Tertiary education enrollment",
                ]

X=combinedColumns[variables]
Y=combinedColumns["Immigrants_total"]

X=sm.add_constant(X)
model=sm.OLS(Y,X)
regression_results=model.fit()
print(regression_results.summary())

print(PCA_regression_results.summary())

#with Emigrants_total as the dependent variable, r-squared was .29
#when using PCA here, r-squared is .452 (on Immigrants_total)
# Out:
# Requirement already satisfied: statsmodels in c:\users\13154\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in c:\users\13154\anaconda3\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\13154\anaconda3\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\13154\anaconda3\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\13154\anaconda3\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\13154\appdata\roaming\python\python312\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\13154\appdata\roaming\python\python312\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\13154\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\13154\anaconda3\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\13154\appdata\roaming\python\python312\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Immigrants_total   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     16.98
# Date:                Sun, 24 Nov 2024   Prob (F-statistic):           7.05e-18
# Time:                        00:07:49   Log-Likelihood:                -2154.7
# No. Observations:                 132   AIC:                             4329.
# Df Residuals:                     122   BIC:                             4358.
# Df Model:                           9
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          5.021e+06   7.39e+06      0.680      0.498    -9.6e+06    1.96e+07
# Birth Rate                     3.799e+04   6.21e+04      0.612      0.542    -8.5e+04    1.61e+05
# Physicians per thousand       -8.231e+04      3e+05     -0.274      0.784   -6.76e+05    5.12e+05
# Life expectancy               -9.273e+04   8.21e+04     -1.130      0.261   -2.55e+05    6.97e+04
# OOP health expenditure        -1.094e+04   1.69e+04     -0.649      0.518   -4.43e+04    2.25e+04
# GDP                            1.062e-06   1.09e-07      9.706      0.000    8.45e-07    1.28e-06
# Unemployment rate              6.855e+04    5.9e+04      1.161      0.248   -4.83e+04    1.85e+05
# Minimum wage                   3.733e+05    1.3e+05      2.871      0.005    1.16e+05    6.31e+05
# Primary education enrollment  -3390.4635   2.36e+04     -0.144      0.886   -5.02e+04    4.34e+04
# Tertiary education enrollment  3.622e+04   1.72e+04      2.104      0.037    2134.138    7.03e+04
# ==============================================================================
# Omnibus:                       57.306   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3248.240
# Skew:                          -0.361   Prob(JB):                         0.00
# Kurtosis:                      27.291   Cond. No.                     7.34e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.34e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       Immigrants_total   R-squared (uncentered):                   0.452
# Model:                            OLS   Adj. R-squared (uncentered):              0.439
# Method:                 Least Squares   F-statistic:                              35.49
# Date:                Sun, 24 Nov 2024   Prob (F-statistic):                    8.62e-17
# Time:                        00:07:49   Log-Likelihood:                         -2176.2
# No. Observations:                 132   AIC:                                      4358.
# Df Residuals:                     129   BIC:                                      4367.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.181e-06   1.19e-07      9.958      0.000    9.47e-07    1.42e-06
# x2          2.599e+04   1.01e+04      2.583      0.011    6078.495    4.59e+04
# x3         -1.358e+04   1.72e+04     -0.788      0.432   -4.77e+04    2.05e+04
# ==============================================================================
# Omnibus:                       65.854   Durbin-Watson:                   1.511
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4281.269
# Skew:                          -0.644   Prob(JB):                         0.00
# Kurtosis:                      30.870   Cond. No.                     1.45e+11
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.45e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
variables=["GDP", "Unemployment rate", "Minimum wage"]

X=combinedColumns[variables]
Y=combinedColumns["Immigrants_total"]

X=sm.add_constant(X)
model=sm.OLS(Y,X)
regression_results=model.fit()
print(regression_results.summary())

#with Emigrants_total as the dependent variable, r-squared was .139
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Immigrants_total   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     48.42
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           5.56e-21
# Time:                        23:56:41   Log-Likelihood:                -2158.2
# No. Observations:                 132   AIC:                             4324.
# Df Residuals:                     128   BIC:                             4336.
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -4.171e+05   5.23e+05     -0.797      0.427   -1.45e+06    6.19e+05
# GDP                1.079e-06   1.07e-07     10.085      0.000    8.68e-07    1.29e-06
# Unemployment rate  7.717e+04   5.83e+04      1.323      0.188   -3.82e+04    1.93e+05
# Minimum wage       3.687e+05   9.58e+04      3.848      0.000    1.79e+05    5.58e+05
# ==============================================================================
# Omnibus:                       57.107   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3574.123
# Skew:                          -0.276   Prob(JB):                         0.00
# Kurtosis:                      28.486   Cond. No.                     5.22e+12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.22e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
variables=["Birth Rate", "Physicians per thousand", "Life expectancy","OOP health expenditure"]
                
X=combinedColumns[variables]
Y=combinedColumns["Emigrants_total"]

X=sm.add_constant(X)
model=sm.OLS(Y,X)
regression_results=model.fit()
print(regression_results.summary())

#if you have Y be for "Immigrants_total" R-sqaured is .08
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Emigrants_total   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.131
# Method:                 Least Squares   F-statistic:                     5.921
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           0.000211
# Time:                        23:58:12   Log-Likelihood:                -2112.8
# No. Observations:                 132   AIC:                             4236.
# Df Residuals:                     127   BIC:                             4250.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                    4.041e+06    4.7e+06      0.859      0.392   -5.26e+06    1.33e+07
# Birth Rate              -1.102e+05    4.3e+04     -2.561      0.012   -1.95e+05   -2.51e+04
# Physicians per thousand  -3.27e+05   1.83e+05     -1.789      0.076   -6.89e+05    3.47e+04
# Life expectancy         -1.561e+04   5.42e+04     -0.288      0.774   -1.23e+05    9.16e+04
# OOP health expenditure   4.217e+04   1.11e+04      3.805      0.000    2.02e+04    6.41e+04
# ==============================================================================
# Omnibus:                      111.118   Durbin-Watson:                   2.119
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1064.270
# Skew:                           2.983   Prob(JB):                    7.89e-232
# Kurtosis:                      15.566   Cond. No.                     2.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
variables=["Primary education enrollment","Tertiary education enrollment"]

X=combinedColumns[variables]
Y=combinedColumns["Immigrants_total"]

X=sm.add_constant(X)
model=sm.OLS(Y,X)
regression_results=model.fit()
print(regression_results.summary())

#with Emigrants_total as the dependent variable, r-squared was .016
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Immigrants_total   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     7.931
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           0.000564
# Time:                        23:59:37   Log-Likelihood:                -2200.6
# No. Observations:                 132   AIC:                             4407.
# Df Residuals:                     129   BIC:                             4416.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                           2.07e+05   3.31e+06      0.063      0.950   -6.33e+06    6.75e+06
# Primary education enrollment  -5342.0002   3.12e+04     -0.171      0.864   -6.71e+04    5.65e+04
# Tertiary education enrollment  5.006e+04   1.27e+04      3.956      0.000     2.5e+04    7.51e+04
# ==============================================================================
# Omnibus:                      220.750   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23954.510
# Skew:                           7.101   Prob(JB):                         0.00
# Kurtosis:                      67.449   Cond. No.                         988.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
variables=["Birth Rate",
                "Infant mortality",
                "Physicians per thousand",
                "Life expectancy",
                "OOP health expenditure",
                "GDP",
                "Unemployment rate",
                "Minimum wage",
                "Primary education enrollment",
                "Tertiary education enrollment",
               ]

X=combinedColumns[variables]
Y=combinedColumns["emig_rate"]

X=sm.add_constant(X)
model=sm.OLS(Y,X)
regression_results=model.fit()
print(regression_results.summary())

#pretty much the same for immig_rate
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              emig_rate   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.242
# Method:                 Least Squares   F-statistic:                     5.175
# Date:                Sun, 24 Nov 2024   Prob (F-statistic):           2.73e-06
# Time:                        00:03:48   Log-Likelihood:                 150.33
# No. Observations:                 132   AIC:                            -278.7
# Df Residuals:                     121   BIC:                            -246.9
# Df Model:                          10
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.8553      0.283      3.021      0.003       0.295       1.416
# Birth Rate                       -0.0061      0.002     -3.667      0.000      -0.009      -0.003
# Infant mortality                 -0.0019      0.001     -1.564      0.121      -0.004       0.001
# Physicians per thousand           0.0018      0.008      0.230      0.819      -0.014       0.018
# Life expectancy                  -0.0062      0.003     -1.796      0.075      -0.013       0.001
# OOP health expenditure            0.0004      0.000      0.865      0.389      -0.001       0.001
# GDP                           -7.387e-15   2.87e-15     -2.578      0.011   -1.31e-14   -1.71e-15
# Unemployment rate                 0.0041      0.002      2.632      0.010       0.001       0.007
# Minimum wage                     -0.0028      0.004     -0.751      0.454      -0.010       0.005
# Primary education enrollment     -0.0012      0.001     -1.973      0.051      -0.002    4.01e-06
# Tertiary education enrollment    -0.0012      0.000     -2.579      0.011      -0.002      -0.000
# ==============================================================================
# Omnibus:                       38.177   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.971
# Skew:                           1.284   Prob(JB):                     2.35e-16
# Kurtosis:                       5.548   Cond. No.                     1.07e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+14. This might indicate that there are
# strong multicollinearity or other numerical problems.
